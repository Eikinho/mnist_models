# %% [markdown]
# # G2
# - Eiki Yamashiro
# - Nicolas Queiroga

# %% [markdown]
# # Importing necessary libraries

# %%
from src.models.Net import Net

# %% [markdown]
# # Results

# %% [markdown]
# ## Artificial Neural Network

# %% [markdown]
# ### Loading Network

# %%
ANN = Net()
ANN.load_model("src/results/ANN.h5")
# Out:
# Metal device set to: Apple M1 Pro
# 2022-09-12 20:59:47.622272: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-09-12 20:59:47.622398: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Network Architecture

# %%
ANN.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (8, 784)                  0
#
#  dense (Dense)               (8, 32)                   25120
#
#  dense_1 (Dense)             (8, 10)                   330
#
# ...
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Network HeatMap

# %%
ANN.plot_confusion_matrix(ANN.y_test, ANN.model.predict(ANN.x_test))
# Out:
#  45/313 [===>..........................] - ETA: 0s
# 2022-09-12 20:59:50.720895: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-09-12 20:59:50.759649: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ## Convolutional Neural Network

# %% [markdown]
# ### Loading Network

# %%
CNN = Net()
CNN.load_model("src/results/CNN.h5")

# %% [markdown]
# ### Network Architecture

# %%
CNN.model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 6)         60
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 16)        880
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dense_2 (Dense)             (None, 120)               48120
#
#  dense_3 (Dense)             (None, 84)                10164
#
#  dense_4 (Dense)             (None, 10)                850
#
# ...
# Total params: 60,074
# Trainable params: 60,074
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Network HeatMap

# %%
CNN.plot_confusion_matrix(CNN.y_test, CNN.model.predict(CNN.x_test))
# Out:
#   1/313 [..............................] - ETA: 1:05
# 2022-09-12 21:02:31.168464: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ## Convolutional Neural Network _With Data Augmentation_

# %% [markdown]
# ### Loading Network

# %%
CNN_Aug = Net()
CNN_Aug.load_model("src/results/CNN_Aug.h5")

# %% [markdown]
# ### Network Architecture

# %%
CNN_Aug.model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 6)         60
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 16)        880
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dense_2 (Dense)             (None, 120)               48120
#
#  dense_3 (Dense)             (None, 84)                10164
#
#  dense_4 (Dense)             (None, 10)                850
#
# ...
# Total params: 60,074
# Trainable params: 60,074
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Network HeatMap

# %%
CNN_Aug.plot_confusion_matrix(CNN_Aug.y_test, CNN_Aug.model.predict(CNN_Aug.x_test))
# Out:
#   1/313 [..............................] - ETA: 1:05
# 2022-09-12 21:02:31.168464: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ## LeNet Network _With Data Augmentation_

# %% [markdown]
# ### Loading Network

# %%
LeNet_Aug = LeNet()
LeNet_Aug.load_model("src/results/LeNet_Aug.h5")

# %% [markdown]
# ### Network Architecture

# %%
LeNet_Aug.model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 6)         60
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 16)        880
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dense_2 (Dense)             (None, 120)               48120
#
#  dense_3 (Dense)             (None, 84)                10164
#
#  dense_4 (Dense)             (None, 10)                850
#
# ...
# Total params: 60,074
# Trainable params: 60,074
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Network HeatMap

# %%
LeNet_Aug.plot_confusion_matrix(LeNet_Aug.y_test, LeNet_Aug.model.predict(LeNet_Aug.x_test))
# Out:
#   1/313 [..............................] - ETA: 1:05
# 2022-09-12 21:02:31.168464: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 3ms/step
